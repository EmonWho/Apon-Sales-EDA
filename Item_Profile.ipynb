# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import drive

# Mount Google Drive to access files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '//content/drive/MyDrive/Dataset/Data for Assessment/Item Profile.csv'

data = pd.read_csv(file_path)

data.head()
# Out:
#    Item Code                                   Item Name Item Category  \
# 0   15554607      Pusti Happy Time Orange Biscuit 180 Gm          Food
# 1   15554606  Pusti Happy Time Orange Full Biscuit 50 Gm          Food
# 2   15554605         Pusti Happy Time Milk Biscuit 50 Gm          Food
# 3   15554604                      Ifad Plan Toast 350 Gm          Food
# 4   15554603           Ifad Choco Delight Biscuit 220 Gm          Food
#
#   Item Sub Category
# 0       Family Pack
# 1    Tiffin Item -1
# 2    Tiffin Item -1
# 3       Family Pack
# 4       Family Pack
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Item Code'].plot(kind='hist', bins=20, title='Item Code')
# ...

# %%
from matplotlib import pyplot as plt
_df_0['index'].plot(kind='hist', bins=20, title='index')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
import pandas as pd


unique_item_names = data['Item Name'].nunique()

print(f'The number of different item names is: {unique_item_names}')
# Out:
# The number of different item names is: 2541

# %%
import pandas as pd


Item_Category_names = data['Item Category'].nunique()

print(f'The number of different item category is: {Item_Category_names}')
# Out:
# The number of different item category is: 6

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame and 'Item Category' is the column with item categories
category_counts = data['Item Category'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar', color='skyblue')
plt.title('Item Category Distribution')
plt.xlabel('Item Category')
plt.ylabel('Number of Items')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2557 entries, 0 to 2556
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Item Code          2557 non-null   int64
#  1   Item Name          2557 non-null   object
#  2   Item Category      2557 non-null   object
#  3   Item Sub Category  2557 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 80.0+ KB
